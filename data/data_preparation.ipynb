# %% [markdown]
# # Data Management

# %% [markdown]
# ## This file download dataset to local ( if necessary )

# %% [markdown]
# ## Imports

# %%
import json
from typing import cast

from constants import *


# import language_tool_python


def enter_ds(name):
    os.makedirs(DATASET_PATH / name, exist_ok=True)
    os.chdir(DATASET_PATH / name)

# %% [markdown]
# ## Beatles

# %%
# chords 

enter_ds("beatles")

# !curl -O "http://isophonics.net/files/annotations/The%20Beatles%20Annotations.tar.gz"
# !tar -xf "The%20Beatles%20Annotations.tar.gz"


beatles = Dataset()
# load_audio()
# print(mirdata)

# %%
import pandas as pd
import os, shutil

# os.environ['https_proxy'] = 'http://172.20.0.113:12798'
# os.environ['http_proxy'] = 'http://172.20.0.113:12798'
os.makedirs(DATASET_PATH / "fma", exist_ok=True)
os.chdir(DATASET_PATH / "fma")

# def download(size):
#     file_name = f"fma_{size}"
#     if not os.path.exists("fma"):
#         print(f"downloading {file_name}")
#         !curl -O "https://os.unil.cloud.switch.ch/fma/{file_name}.zip"
#         !7z e fma_{size}.zip -y
# 
# size = "medium"
# download(size)
# 
# # handle metadata
# if not os.path.exists("fma_metadata.zip"):
#     print("downloading fma_metadata")
#     !curl -O "https://os.unil.cloud.switch.ch/fma/fma_metadata.zip"
# 
# !7z e fma_metadata.zip -y

# os.chdir(DATASET_PATH / "fma_metadata")
start_row = 0
chunk_size = 10000
tracks = pd.read_csv("raw_tracks.csv", skiprows=0, chunksize=chunk_size)
print("load done")
for track in tracks:
    for index, row in track.iterrows():
        # print(row)
        track_id = f"{int(row['track_id']):0>6}"
        # print(row['track_genres'])
        if isinstance(row['track_genres'], float):
            continue
        genres: str = row['track_genres'][1:-1].replace("\'", "\"")
        genres = genres.split(", {")[0]
        # print(genres)
        genre = json.loads(genres)
        genre_title = genre['genre_title'].replace("\'", "")
        os.makedirs(f"./{genre_title}", exist_ok=True)
        if os.path.exists(f"./{track_id}.mp3") and not os.path.exists(f"./{genre_title}/{track_id}.mp3"):
            print(f"file: {track_id}, title: {genre_title}")
            shutil.move(f"./{track_id}.mp3", f"./{genre_title}/")
# Out:
# load done
# file: 000002, title: Hip-Hop
# file: 000003, title: Hip-Hop
# file: 000005, title: Hip-Hop
# file: 000010, title: Pop
# file: 000134, title: Hip-Hop
# file: 000136, title: Loud-Rock
# file: 000139, title: Folk
# file: 000140, title: Folk
# file: 000141, title: Folk
# file: 000148, title: Avant-Garde
# file: 000181, title: Lo-Fi
# file: 000182, title: Lo-Fi
# file: 000190, title: Folk
# file: 000193, title: Folk
# file: 000194, title: Folk
# file: 000197, title: Folk
# file: 000198, title: Folk
# file: 000200, title: Folk
# file: 000203, title: Folk
# file: 000204, title: Folk
# file: 000207, title: Folk
# file: 000208, title: Folk
# file: 000209, title: Folk
# file: 000210, title: Folk
# file: 000211, title: Folk
# file: 000212, title: Folk
# file: 000213, title: Pop
# file: 000237, title: Jazz
# file: 000247, title: Rock
# file: 000249, title: Rock
# file: 000255, title: Rock
# file: 000256, title: Metal
# file: 000257, title: Metal
# file: 000258, title: Metal
# file: 000341, title: Post-Punk
# file: 000343, title: Post-Punk
# file: 000352, title: Post-Punk
# file: 000368, title: Post-Punk
# file: 000369, title: Post-Punk
# file: 000397, title: Electronic
# file: 000398, title: Electronic
# file: 000399, title: Electronic
# file: 000400, title: Electronic
# file: 000405, title: Electronic
# file: 000414, title: Electronic
# file: 000424, title: Avant-Garde
# file: 000425, title: Avant-Garde
# file: 000458, title: Krautrock
# file: 000459, title: Krautrock
# file: 000512, title: Lo-Fi
# file: 000534, title: Folk
# file: 000535, title: Folk
# file: 000536, title: Folk
# file: 000537, title: Folk
# file: 000540, title: Folk
# file: 000546, title: Folk
# file: 000550, title: Electronic
# file: 000564, title: Rock
# file: 000573, title: Punk
# file: 000574, title: Punk
# file: 000583, title: Hip-Hop
# file: 000584, title: Hip-Hop
# file: 000585, title: Hip-Hop
# file: 000590, title: Jazz: Vocal
# file: 000591, title: Jazz: Vocal
# file: 000592, title: Jazz: Vocal
# file: 000593, title: Jazz: Vocal
# file: 000602, title: Folk
# file: 000603, title: Folk
# file: 000605, title: Rock
# file: 000608, title: Rock
# file: 000615, title: Electroacoustic
# file: 000619, title: Folk
# file: 000620, title: Folk
# file: 000621, title: Folk
# file: 000625, title: Folk
# file: 000629, title: Folk
# file: 000631, title: Folk
# file: 000633, title: Rock
# file: 000635, title: Rock
# file: 000664, title: Electronic
# file: 000665, title: Electronic
# file: 000666, title: Reggae - Dub
# file: 000667, title: Reggae - Dub
# file: 000668, title: Hip-Hop
# file: 000669, title: Hip-Hop
# file: 000672, title: Hip-Hop
# file: 000673, title: Hip-Hop
# file: 000674, title: Hip-Hop
# file: 000676, title: Hip-Hop
# file: 000677, title: Hip-Hop
# file: 000679, title: Hip-Hop
# file: 000680, title: Hip-Hop
# file: 000681, title: Hip-Hop
# file: 000684, title: Hip-Hop
# file: 000686, title: Hip-Hop
# file: 000690, title: Rock
# file: 000694, title: Hip-Hop
# file: 000695, title: Hip-Hop
# file: 000696, title: Loud-Rock
# file: 000698, title: Loud-Rock
# file: 000701, title: Loud-Rock
# file: 000702, title: Loud-Rock
# file: 000703, title: Loud-Rock
# file: 000704, title: Latin America
# file: 000705, title: Latin America
# file: 000706, title: Latin America
# file: 000707, title: Latin America
# file: 000708, title: Latin America
# file: 000709, title: Latin America
# file: 000714, title: Folk
# file: 000715, title: Folk
# file: 000716, title: Folk
# file: 000717, title: Folk
# file: 000718, title: Folk
# file: 000720, title: Rock
# file: 000734, title: Disco
# file: 000735, title: Disco
# file: 000736, title: Disco
# file: 000737, title: Disco
# file: 000738, title: Disco
# file: 000739, title: Disco
# file: 000740, title: Disco
# file: 000741, title: Disco
# file: 000742, title: Disco
# file: 000743, title: Disco
# file: 000744, title: Disco
# file: 000745, title: Disco
# file: 000747, title: Disco
# file: 000748, title: Disco
# file: 000749, title: Disco
# file: 000750, title: Disco
# file: 000751, title: Disco
# file: 000752, title: Disco
# file: 000753, title: Disco
# file: 000754, title: Disco
# file: 000755, title: Disco
# file: 000756, title: Disco
# file: 000757, title: Disco
# file: 000758, title: Disco
# file: 000759, title: Disco
# file: 000760, title: Disco
# file: 000761, title: Disco
# file: 000762, title: Disco
# file: 000763, title: Disco
# file: 000764, title: Disco
# file: 000765, title: Disco
# file: 000766, title: Disco
# file: 000767, title: Disco
# file: 000768, title: Disco
# file: 000769, title: Disco
# file: 000770, title: Disco
# file: 000771, title: Disco
# file: 000772, title: Disco
# file: 000773, title: Disco
# file: 000774, title: Disco
# file: 000775, title: Disco
# file: 000776, title: Disco
# file: 000777, title: Rock
# file: 000814, title: Folk
# file: 000819, title: Avant-Garde
# file: 000820, title: Avant-Garde
# file: 000821, title: Pop
# file: 000822, title: Pop
# file: 000823, title: Pop
# file: 000824, title: Rock
# file: 000825, title: Rock
# file: 000826, title: Rock
# file: 000829, title: Rock
# file: 000830, title: Rock
# file: 000831, title: Jazz: Vocal
# file: 000832, title: Jazz: Vocal
# file: 000833, title: Jazz: Vocal
# file: 000834, title: Jazz: Vocal
# file: 000835, title: Jazz: Vocal
# file: 000853, title: International
# file: 000854, title: Noise
# file: 000855, title: Rock
# file: 000858, title: Rock
# file: 000861, title: Rock
# file: 000863, title: Rock
# file: 000868, title: Drone
# file: 000878, title: Electronic
# file: 000881, title: Electronic
# file: 000889, title: Electronic
# file: 000890, title: Free-Folk
# file: 000891, title: Free-Folk
# file: 000892, title: Free-Folk
# file: 000893, title: Free-Folk
# file: 000894, title: Free-Folk
# file: 000895, title: Free-Folk
# file: 000896, title: Punk
# file: 000897, title: Noise
# file: 000898, title: Noise
# file: 000992, title: Rock
# file: 000993, title: Rock
# file: 000995, title: Noise
# file: 000997, title: Noise
# file: 000998, title: Noise
# file: 001014, title: Metal
# file: 001015, title: Metal
# file: 001016, title: Metal
# file: 001017, title: Metal
# file: 001018, title: Metal
# file: 001022, title: Jazz
# file: 001023, title: Jazz
# file: 001028, title: Rock
# file: 001029, title: Rock
# file: 001039, title: Noise-Rock
# file: 001040, title: Noise-Rock
# file: 001041, title: Psych-Rock
# file: 001042, title: Blues
# file: 001043, title: Blues
# file: 001044, title: Blues
# file: 001045, title: Blues
# file: 001046, title: Blues
# file: 001047, title: Blues
# file: 001048, title: Blues
# file: 001052, title: Rock
# file: 001058, title: Jazz
# file: 001059, title: Jazz
# file: 001060, title: Jazz
# file: 001061, title: Jazz
# file: 001063, title: Jazz
# file: 001064, title: Jazz
# file: 001066, title: Audio Collage
# file: 001068, title: Audio Collage
# file: 001069, title: Audio Collage
# file: 001071, title: Audio Collage
# file: 001072, title: Audio Collage
# file: 001073, title: Audio Collage
# file: 001075, title: Audio Collage
# file: 001082, title: International
# file: 001083, title: Avant-Garde
# file: 001085, title: Electronic
# file: 001086, title: Electronic
# file: 001087, title: Rock
# file: 001088, title: Electronic
# file: 001089, title: Electronic
# file: 001093, title: Field Recordings
# file: 001095, title: Field Recordings
# file: 001102, title: Rock
# file: 001105, title: Rock
# file: 001106, title: Rock
# file: 001107, title: Rock
# file: 001108, title: Rock
# file: 001117, title: Rock
# file: 010427, title: Electronic
# file: 010434, title: Audio Collage
# file: 010435, title: Audio Collage
# file: 010437, title: Audio Collage
# file: 010438, title: Folk
# file: 010439, title: Folk
# file: 010440, title: Folk
# file: 010441, title: Folk
# file: 010442, title: Folk
# file: 010443, title: Folk
# file: 010444, title: Folk
# file: 010445, title: Folk
# file: 010447, title: Folk
# file: 010449, title: Folk
# file: 010451, title: Folk
# file: 010456, title: Folk
# file: 010458, title: Folk
# file: 010459, title: Folk
# file: 010460, title: Folk
# file: 010480, title: Folk
# file: 010481, title: Folk
# file: 010482, title: Folk
# file: 010483, title: Folk
# file: 010484, title: Folk
# file: 010485, title: Folk
# file: 010521, title: Unclassifiable
# file: 010525, title: Unclassifiable
# file: 010527, title: Unclassifiable
# file: 010529, title: Unclassifiable
# file: 010531, title: Unclassifiable
# file: 010535, title: Unclassifiable
# file: 010537, title: Unclassifiable
# file: 010541, title: Unclassifiable
# file: 010552, title: Unclassifiable
# file: 010554, title: Unclassifiable
# file: 010556, title: Unclassifiable
# file: 010558, title: Unclassifiable
# file: 010567, title: Singer-Songwriter
# file: 010568, title: Singer-Songwriter
# file: 010575, title: Psych-Folk
# file: 010577, title: Psych-Folk
# file: 010621, title: Electronic
# file: 010623, title: Electronic
# file: 010627, title: Electronic
# file: 010630, title: Electronic
# file: 010631, title: Electronic
# file: 010666, title: Hip-Hop
# file: 010668, title: Industrial
# file: 010669, title: Industrial
# file: 010670, title: Industrial
# file: 010671, title: Industrial
# file: 010672, title: Industrial
# file: 010673, title: Industrial
# file: 010674, title: Industrial
# file: 010675, title: Industrial
# file: 010676, title: Industrial
# file: 010677, title: Industrial
# file: 010678, title: Folk
# file: 010679, title: Folk
# file: 010680, title: Folk
# file: 010681, title: Folk
# file: 010682, title: Folk
# file: 010683, title: Folk
# file: 010684, title: Folk
# file: 010685, title: Folk
# file: 010686, title: Folk
# file: 010689, title: Ambient
# file: 010690, title: Ambient
# file: 010692, title: Ambient
# file: 010693, title: Hip-Hop
# file: 010694, title: Hip-Hop
# file: 010695, title: Hip-Hop
# file: 010696, title: Hip-Hop
# file: 010697, title: Hip-Hop
# file: 010698, title: Hip-Hop
# file: 010699, title: Hip-Hop
# file: 010728, title: Electronic
# file: 010737, title: Jazz: Out
# file: 010739, title: Jazz: Out
# file: 010740, title: Jazz: Out
# file: 010741, title: Jazz: Out
# file: 010742, title: Jazz: Out
# file: 010805, title: Pop
# file: 010806, title: Pop
# file: 010807, title: Pop
# file: 010808, title: Pop
# file: 010809, title: Pop
# file: 010810, title: Pop
# file: 010815, title: Hip-Hop
# file: 010824, title: Rock
# file: 010826, title: Rock
# file: 010830, title: Rock
# file: 010833, title: Hardcore
# file: 010834, title: Hardcore
# file: 010843, title: Hardcore
# file: 010868, title: Hardcore
# file: 010879, title: Power-Pop
# file: 010880, title: Power-Pop
# file: 010881, title: Power-Pop
# file: 010883, title: Power-Pop
# file: 010884, title: Power-Pop
# ...
# file: 148981, title: Ambient Electronic
# file: 148982, title: Ambient Electronic
# file: 155296, title: Soundtrack
# file: 155297, title: Soundtrack
# file: 155298, title: Folk
# file: 155306, title: Folk
# file: 155307, title: Avant-Garde
# file: 155314, title: Punk

# %%
ARTIFACT_PATH = "../core/artifacts/"
ANN_PATH = ARTIFACT_PATH + "coco_annotations/"
CAPTIONS = ANN_PATH + "captions_train2014.json"
PREPROCESSED = ANN_PATH + "remixer-pica.json"

SIMILARITY_PATH = ARTIFACT_PATH + "coco_clip_new/"
IDXS = SIMILARITY_PATH + "okvqa_qa_line2sample_idx_train2014.json"
QUESTION_FEATURES = SIMILARITY_PATH + "coco_clip_vitb16_train2014_okvqa_question.npy"
IMG_FEATURES = SIMILARITY_PATH + "coco_clip_vitb16_train2014_okvqa_convertedidx_image.npy"

clip_processor = ARTIFACT_PATH + "transformers/openai/clip-vit-base-patch16"
clip_onnx = ARTIFACT_PATH + "onnx/clip.onnx"

# %%
# install packages, answering all with yes
# !zenml integration install great_expectations s3 dash -y

# !zenml artifact-store register remixer_s3_great_expectations \
    --flavor=s3 \
    --path=s3: // remixer-pica-zenml-greatexpectations  # Register S3 bucket allowing ZenML write access

# !zenml data-validator register great_expectations \
    --flavor=great_expectations

# set as active stack
# !zenml stack register remixer-great-expectations \
    -o default \
    -a remixer_s3_great_expectations \
    -dv great_expectations \
    --set

# %% [markdown]
# ## Exploration

# %%
s3_bucket_name = "remixer-pica"  # objects are placed into buckets
s3_directory_path = "images"  # buckets can contain "folders" for organization
# we combine this information into a base URL format for the data:
s3_url = f"https://{s3_bucket_name}.s3.us-west-1.amazonaws.com/{s3_directory_path}"
s3_url

# %%
person_idx = 1
image_idx = 1
img_url = f"{s3_url}/{str(person_idx).zfill(3)}_{str(image_idx).zfill(2)}.png"
print(img_url)
Image(url=img_url, width=360)

# %% [markdown]
# ## Local Annotation
# - Note: not used since annotations are obtained with Scale.ai, but here for future use

# %%
username = "remixer@localhost"
password = "moonshine"

# %env LABEL_STUDIO_USERNAME={username}
# %env LABEL_STUDIO_PASSWORD={password}

# %%
config_file = ngrok.conf.DEFAULT_NGROK_CONFIG_PATH
config_file_exists = os.path.exists(config_file)
config_file_contents = !cat {config_file}

auth_token_found = config_file_exists \
                   and config_file_contents \
                   and "authtoken" in config_file_contents[0] \
                   and ": exit" not in config_file_contents  # state if interrupted

if not auth_token_found:
    print("Enter your ngrok auth token, which can be copied from https://dashboard.ngrok.com/auth")
    # !ngrok authtoken {getpass.getpass()}

# %%
LABEL_STUDIO_PORT = 8081
# %env LABEL_STUDIO_PORT={LABEL_STUDIO_PORT}
# create ngrok tunnel for label_studio
https_tunnel = ngrok.connect(LABEL_STUDIO_PORT, bind_tls=True)
print(https_tunnel)

# %%
# Start Label Studio 
import subprocess

subprocess.run("conda deactivate", shell=True, check=True)

# !python3 -m venv label-env
# !conda deactivate
# !source label-env/bin/activate
# !pip install -qqq label-studio
# !export LABEL_STUDIO_PORT=8081
# !label-studio start --port=$LABEL_STUDIO_PORT

# %%
print(https_tunnel.public_url)
print("u:", username)
print("p:", password)

# %% [markdown]
# ### Uploading Data

# %%
img_urls = []
for person_idx in range(1, 104):
    for image_idx in range(1, 13):
        img_urls.append(f"{s3_url}/{str(person_idx).zfill(3)}_{str(image_idx).zfill(2)}.png")
len(img_urls)

# %% [markdown]
# ### Teardown

# %%
# Run in the terminal
# !conda deactivate
# !conda activate remixer

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Load Data
# - Depends on Annotation Source

# %% [markdown]
# #### LabelStudio

# %% [markdown]
# #### Scale

# %%
# Want to convert s3_filenames -> img_urls to save to df
s3_filenames[0], img_urls[0]

# %%
# img_urls is sorted, so we save the sorted filenames and pull the url for the corresponding filename
ordered_filenames = sorted(s3_filenames)
ordered_filenames[0], img_urls[ordered_filenames.index(s3_filenames[0])]

# %%
s3_links = [img_urls[ordered_filenames.index(s3_filenames[id])] for id in range(len(img_urls))]
s3_links[0]

# %%
image_ids = []
question_ids = []
num_gen = 0

while num_gen < len(df):
    rand_num = random.randint(10000, 999999)
    if rand_num not in keys:
        image_ids.append(rand_num)
        question_ids.append(str(rand_num) + '5')
        num_gen += 1

print(len(df), len(image_ids), len(question_ids), image_ids[0], question_ids[0])

# %% [markdown]
# ### Saving preprocessed data

# %%
train_idx = json.load(
    open(
        IDXS,
        "r",
    )
)
train_feature = np.load(QUESTION_FEATURES)
image_train_feature = np.load(
    IMG_FEATURES
)
train_feature.shape, len(train_idx), image_train_feature.shape

# %%
combine_ids = [str(image_id) + "<->" + str(question_id) for image_id, question_id in
               zip(list(df['image_id']), list(df['question_id']))]
num_idx = list(range(9009, 9009 + len(df)))
num_idx = list(map(str, num_idx))
idx_add = dict(zip(num_idx, combine_ids))
train_idx.update(idx_add)
len(train_idx)

# %%
clip_session = InferenceSession(str(clip_onnx))
clip_processor = CLIPProcessor.from_pretrained(clip_processor)

data_path = DOWNLOADED_DATA_DIRNAME / "remixer-pica/images/"
images = [str(data_path / f) for f in os.listdir(str(data_path)) if os.path.isfile(os.path.join(str(data_path), f))]
images_pil = []

for image in images:
    image_pil = Image.open(image)
    if image_pil.mode != "RGB":
        image_pil = image_pil.convert(mode="RGB")
    images_pil.append(image_pil)

inputs = clip_processor(text=list(df['question']), images=images_pil, return_tensors="np", padding=True)
outputs = clip_session.run(
    output_names=["logits_per_image", "logits_per_text", "text_embeds", "image_embeds"], input_feed=dict(inputs)
)

train_feature = np.concatenate((train_feature, outputs[2]))
image_train_feature = np.concatenate((image_train_feature, outputs[3]))
train_feature.shape, image_train_feature.shape

# %%
with open(IDXS, "w") as f: json.dump(train_idx, f)
with open(QUESTION_FEATURES, 'wb') as f: np.save(f, train_feature)
with open(IMG_FEATURES, 'wb') as f: np.save(f, image_train_feature)

# %% [markdown]
# ## Data Validation

# %% [markdown]
# ### Define ZenML Steps

# %%
from zenml.steps import BaseParameters, step, Output


class DataLoaderParameters(BaseParameters):
    reference_data: bool = True


@step
def importer(
        params: DataLoaderParameters,
) -> Output(dataset=pd.DataFrame, condition=bool):
    # Load labeled projects
    df = pd.read_json(PREPROCESSED)
    return df, params.reference_data

# %%
# instantiate a builtin Great Expectations data profiling step
ge_profiler_params = GreatExpectationsProfilerParameters(
    expectation_suite_name="remixer-pica",
    data_asset_name="remixer-pica_test_df",
)
ge_profiler_step = GreatExpectationsProfilerStep(params=ge_profiler_params)

# instantiate a builtin Great Expectations data validation step
ge_validator_params = GreatExpectationsValidatorParameters(
    expectation_suite_name="remixer-pica",
    data_asset_name="remixer-pica_test_df",
)
ge_validator_step = GreatExpectationsValidatorStep(params=ge_validator_params)

# %%
@step
def analyze_result(
        result: CheckpointResult,
) -> str:
    """Analyze the Great Expectations validation result and return a true/false value indicating
    whether it passed or failed."""
    step_env = cast(StepEnvironment, Environment()[STEP_ENVIRONMENT_NAME])
    pipeline_name = step_env.pipeline_name
    pipeline_run_id = step_env.pipeline_run_id
    step_name = step_env.step_name
    pipeline_context = f"Pipeline {pipeline_name}, with run {pipeline_run_id}, in step {step_name} produced the following output:\n\n"
    if result.success:
        message = pipeline_context + "Great Expectations data validation was successful!"
    else:
        message = pipeline_context + "Great Expectations data validation failed!"
    print(message)
    return message

# %% [markdown]
# ### Define ZenML Pipelines

# %%
docker_settings = DockerSettings(required_integrations=[GREAT_EXPECTATIONS])


@pipeline(enable_cache=False, settings={"docker": docker_settings})
def profiling_pipeline(
        importer, profiler
):
    """Data profiling pipeline for Great Expectations.

    The pipeline imports a reference dataset from a source then uses the builtin
    Great Expectations profiler step to generate an expectation suite (i.e.
    validation rules) inferred from the schema and statistical properties of the
    reference dataset.

    Args:
        importer: reference data importer step
        profiler: data profiler step
    """
    dataset, _ = importer()
    profiler(dataset)

# %%
@pipeline(enable_cache=False, settings={"docker": docker_settings})
def validation_pipeline(
        importer, validator, checker
):
    """Data validation pipeline for Great Expectations.

    The pipeline imports a test data from a source, then uses the builtin
    Great Expectations data validation step to validate the dataset against
    the expectation suite generated in the profiling pipeline.

    Args:
        importer: test data importer step
        validator: dataset validation step
        checker: checks the validation results
    """
    dataset, condition = importer()
    results = validator(dataset, condition)
    message = checker(results)

# %% [markdown]
# ### Run the pipelines

# %%
profiling_pipeline(
    importer=importer(params=DataLoaderParameters(reference_data=True)),
    profiler=ge_profiler_step,
).run()

# %%
validation_pipeline(
    importer=importer(params=DataLoaderParameters(reference_data=True)),
    validator=ge_validator_step,
    checker=analyze_result(),
).run()

# %% [markdown]
# ### Post execution workflow

# %%
def start_pipeline_visualizer(name: str):
    from zenml.integrations.dash.visualizers.pipeline_run_lineage_visualizer import (
        PipelineRunLineageVisualizer,
    )

    latest_run = get_pipeline(name).runs[-1]
    PipelineRunLineageVisualizer().visualize(latest_run)

# %%
def visualize_results(pipeline_name: str, step_name: str) -> None:
    pipeline = get_pipeline(pipeline_name)
    last_run = pipeline.runs[-1]
    step = last_run.get_step(step=step_name)
    GreatExpectationsVisualizer().visualize(step)

# %%
# start_pipeline_visualizer("profiling_pipeline")

# %%
# start_pipeline_visualizer("validation_pipeline")

# %%
# visualize_results("profiling_pipeline", "profiler")

# %%
# visualize_results("validation_pipeline", "validator")
